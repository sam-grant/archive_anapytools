# %%
from anapytools import read_data as rd 
from anapytools import parallelise as pa

# %%
file_list = rd.get_file_list(defname='nts.sgrant.CosmicCRYExtractedCatTriggered.MDC2020ae_best_v1_3.root', quiet=False)
def process_function(filename):
    file = rd.read_file(filename, quiet=True)
    return 
pa.multithread(process_function, file_list)
# Out:
# ---> Getting file list for nts.sgrant.CosmicCRYExtractedCatTriggered.MDC2020ae_best_v1_3.root.
# Done!
#
# ---> Starting multithreading...
#
#
# nts.sgrant.CosmicCRYExtractedCatTriggered.MDC2020ae_best_v1_3.001205_00000025.root processed successfully! (1.0% complete)
#
# nts.sgrant.CosmicCRYExtractedCatTriggered.MDC2020ae_best_v1_3.001205_00000011.root processed successfully! (2.1% complete)
#
# nts.sgrant.CosmicCRYExtractedCatTriggered.MDC2020ae_best_v1_3.001205_00000030.root processed successfully! (3.1% complete)
#
# nts.sgrant.CosmicCRYExtractedCatTriggered.MDC2020ae_best_v1_3.001205_00000029.root processed successfully! (4.2% complete)
#
# nts.sgrant.CosmicCRYExtractedCatTriggered.MDC2020ae_best_v1_3.001205_00000002.root processed successfully! (5.2% complete)
#
# nts.sgrant.CosmicCRYExtractedCatTriggered.MDC2020ae_best_v1_3.001205_00000032.root processed successfully! (6.2% complete)
#
# ...
